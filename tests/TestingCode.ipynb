# %% [markdown]
# ### Testing the Code

# %% [markdown]
# We test here the trajectory computations from the given input file defined in the main folder.

# %%
using TOML 
include(joinpath(@__DIR__, "..", "src", "utils.jl"))

input_file = joinpath(@__DIR__, "..", "main", "input_values.toml")
input_parameters = TOML.parsefile(input_file) 

println("=== Input Parameters === \n") 
pretty_print_table(input_parameters) #pretty_print_dict(input_parameters)
println("\n")


main_file_path = joinpath(@__DIR__, "..", "main", "run_trajectory.jl")
include( main_file_path )
# Out:
# === Input Parameters ===
#
# distance_TS = 80.0                                            n_grid = 20
# plasma_model = vertical_turning                               Inner_Solar_system_velocity = 400000.0
# beta_angle = -10.0                                            q_over_m_value = 500.0
# mode = full                                                   B_mag_ISM = 1.2e-9
# dt = 1500.0                                                   plane = xz
# alpha_angle = 180.0                                           plot_vectors = true
# plot_color = speed                                            dist_measure = spherical
# B_direction_Heliopause = 1.0                                  ISM_plasma_velocity = 26000.0
# B_mag_Heliopause = 1.5e-10                                    distance_Turning = 7.0
# x0_position = 125.0                                           distance_HP = 100.0
# z0_position = 1.0                                             beta_value = 1.0
# max_time = 8.0                                                min_time = 0.0
# plot_sun = false                                              y0_position = 0.0
# Heliosheath_plasma_velocity = 100000.0
#
#
# --- Solution Characteristics ---
# Integration time: 0.0 → 8.0 years
# Solution size: (6, 168309)
