# %% [markdown]
# ### Testing the Code

# %% [markdown]
# We test here the trajectory computations from the given input file defined in the main folder.

# %%
using TOML 
include(joinpath(@__DIR__, "..", "src", "utils.jl"))

input_file = joinpath(@__DIR__, "..", "main", "input_values.toml")
input_parameters = TOML.parsefile(input_file) 

println("=== Input Parameters === \n") 
pretty_print_table(input_parameters) #pretty_print_dict(input_parameters)
println("\n")


main_file_path = joinpath(@__DIR__, "..", "main", "run_trajectory.jl")
include( main_file_path )
# Out:
# === Input Parameters ===
#
# distance_TS = 80.0                                            Heliosheath_plasma_velocity = 100000.0
# plasma_model = straight_straight                              n_grid = 20
# beta_angle = 0.0                                              Inner_Solar_system_velocity = 400000.0
# mode = full                                                   q_over_m_value = 5.0
# dt = 1200.0                                                   B_mag_ISM = 6.0e-10
# alpha_angle = 180.0                                           plane = xz
# plot_color = speed                                            plot_vectors = true
# B_direction_Heliopause = 1.0                                  dist_measure = flat
# B_mag_Heliopause = 1.5e-10                                    ISM_plasma_velocity = 26000.0
# x0_position = 110.0                                           distance_Turning = 5.0
# save_fig = false                                              distance_HP = 100.0
# ...
