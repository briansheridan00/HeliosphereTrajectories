# %% [markdown]
# ### Testing the code which is contained within the separate files

# %%
using Pkg 
using TOML 
using Dates 
using Statistics 
using Random  

using LinearAlgebra
using DifferentialEquations

# %%
include(joinpath(@__DIR__, "..", "main", "run_trajectory.jl"))
# Out:
# --- Solution Characteristics ---
# Integration time: 0.0 → 8.0 years
# Solution size: (6, 252462)
